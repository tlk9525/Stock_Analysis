# %% [markdown]
# # StockLens AI — QLoRA fine-tuning
#
# Attach two Kaggle Datasets before running: `stocklens-sft` (the generated JSONL files) and `stocklens-training` (this training folder). Turn on GPU and Internet.

# %%
# !pip install -q -U -r /kaggle/input/stocklens-training/requirements-kaggle.txt

# %%
import os
os.environ['STOCKLENS_DATA_DIR'] = '/kaggle/input/stocklens-sft'
os.environ['STOCKLENS_BASE_MODEL'] = 'Qwen/Qwen3-4B'
# !python /kaggle/input/stocklens-training/kaggle_train_stocklens.py

# %% [markdown]
# Download `/kaggle/working/stocklens-qwen3-4b-lora` after training. Review `eval_results.json` before importing the adapter into Ollama.
